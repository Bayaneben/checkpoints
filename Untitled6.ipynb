# %% [markdown]
# #  data preprocessing and visualization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("kc_house_data.csv")
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
s , ax = plt.subplots( figsize =( 30 , 20 ) )
cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )
s = sns.heatmap( df.corr(), cmap = cmap,square=True, cbar_kws={ 'shrink' : .9 }, ax=ax, annot = True, annot_kws = { 'fontsize' : 12 } )

# %%
corr=df.corr()
corr
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %%
l=corr.iloc[:,1].sort_values(ascending=False)
l
# Out:
# price            1.000000
# sqft_living      0.702035
# grade            0.667434
# sqft_above       0.605567
# sqft_living15    0.585379
# bathrooms        0.525138
# view             0.397293
# sqft_basement    0.323816
# bedrooms         0.308350
# lat              0.307003
# waterfront       0.266369
# floors           0.256794
# yr_renovated     0.126434
# sqft_lot         0.089661
# sqft_lot15       0.082447
# yr_built         0.054012
# condition        0.036362
# long             0.021626
# id              -0.016762
# zipcode         -0.053203
# Name: price, dtype: float64

# %%
x=df['sqft_living']
y=df['price']
plt.xlabel('sqft_living')
plt.ylabel('price')
plt.scatter(x, y)

# %%
l=sns.FacetGrid(df,col="grade")
l.map(plt.hist,"price",bins=10)

# %%
sns.boxplot(data=df,x ='grade', y= "price")
# Out:
# <AxesSubplot:xlabel='grade', ylabel='price'>

# %%
x=df['sqft_above']
y=df['price']
plt.xlabel('sqft_above')
plt.ylabel('price')
plt.scatter(x, y)

# %%
x=df['sqft_living15']
y=df['price']
plt.xlabel('sqft_living15')
plt.ylabel('price')
plt.scatter(x, y)

# %%
f, ax = plt.subplots(figsize=(20, 20))
sns.boxplot(data=df,x ='bathrooms', y= "price")
# Out:
# <AxesSubplot:xlabel='bathrooms', ylabel='price'>

# %% [markdown]
# # Feature selection

# %% [markdown]
# - Id and date are not important to predict price so we are discarding it
# - From the correlation map :  the zipcode, condition, sqft_lot15, and sqft_lot have a low correlation with the price (correlation value less than 0.1 and greater than -0.1 ),  thus, they are not of any significance in predicting price

# %%
data = df[['price','sqft_living','grade', 'sqft_above', 'sqft_living15','bathrooms','view',
                     'sqft_basement','bedrooms','floors','waterfront','yr_built','yr_renovated','lat','long']]
data
# Out:
#           price  sqft_living  grade  sqft_above  sqft_living15  bathrooms  \
# 0      221900.0         1180      7        1180           1340       1.00
# 1      538000.0         2570      7        2170           1690       2.25
# 2      180000.0          770      6         770           2720       1.00
# 3      604000.0         1960      7        1050           1360       3.00
# 4      510000.0         1680      8        1680           1800       2.00
# ...         ...          ...    ...         ...            ...        ...
# 21608  360000.0         1530      8        1530           1530       2.50
# 21609  400000.0         2310      8        2310           1830       2.50
# 21610  402101.0         1020      7        1020           1020       0.75
# 21611  400000.0         1600      8        1600           1410       2.50
# 21612  325000.0         1020      7        1020           1020       0.75
#
#        view  sqft_basement  bedrooms  floors  waterfront  yr_built  \
# ...

# %% [markdown]
# # SPLITTING DATA INTO TRAINING AND TESTING SET

# %% [markdown]
# splitting dataset into 20% of test data and 80% for training the model

# %%
features=['sqft_living','grade', 'sqft_above', 'sqft_living15','bathrooms','view','sqft_basement','bedrooms','floors','waterfront','yr_built','yr_renovated','lat','long']
X = data[features]
Y = data['price']

# %% [markdown]
# # Applying linear regression model (example : sqft_living)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
x_train, x_test , y_train, y_test = train_test_split(data['sqft_living'] , Y , test_size= 0.2)
x_train=np.array(x_train).reshape(-1,1)
x_test=np.array(x_test).reshape(-1,1)
y_train=np.array(y_train).reshape(-1,1)
y_test=np.array(y_test).reshape(-1,1)
model = LinearRegression()
model.fit(x_train , y_train)
y_pred = model.predict(x_test)
plt.scatter(x_test,y_test,color="r")
plt.title("Linear Regression")
plt.ylabel("price")
plt.xlabel("sqft_living")
plt.plot(x_test,model.predict(x_test),color="k")
plt.show()

# %% [markdown]
# In the LinearRegression plot, the red points are the actual outputs where the black line represents the predicted values.
# we detect also an outlier (sqft_living=10000)

# %% [markdown]
# # Measure the performance of linear regression (example : sqft_living)

# %%
from sklearn.metrics import mean_squared_error
from sklearn import metrics
print("MSE", mean_squared_error(y_test,y_pred))
print("R squared", metrics.r2_score(y_test,y_pred))
# Out:
# MSE 69556991706.04018
# R squared 0.49539447459065467

# %% [markdown]
# # Applying multiple-linear regression

# %%
x_train1, x_test1 , y_train1, y_test1 = train_test_split(X , Y , test_size= 0.2)
model.fit(x_train1 , y_train1)
y_pred1 = model.predict(x_test1)
from sklearn.metrics import mean_squared_error
from sklearn import metrics
print("MSE", mean_squared_error(y_test1,y_pred1))
print("R squared", metrics.r2_score(y_test1,y_pred1))
# Out:
# MSE 41771305884.850624
# R squared 0.6962269101503727

# %% [markdown]
# We note that the R squared metric has improved from linear to multiple linear regression

# %% [markdown]
# # polynomial regression

# %%
from sklearn.preprocessing import PolynomialFeatures
model = LinearRegression()
poly = PolynomialFeatures(degree=2)
poly.fit_transform(x_train)
model.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
poly.fit_transform(x_test)
y_pred = model.predict(x_test)
print("MSE: ", metrics.mean_squared_error(y_test,y_pred))
print("R squared: ", metrics.r2_score(y_test,y_pred))
# Out:
# MSE:  69556991706.04018
# R squared:  0.49539447459065467

# %% [markdown]
# *******Using Multiple features**********

# %%
x_train1, x_test1 , y_train1, y_test1 = train_test_split(X , Y , test_size= 0.2)
from sklearn.preprocessing import PolynomialFeatures
model = LinearRegression()
poly = PolynomialFeatures(degree=2)
poly.fit_transform(x_train1)
model.fit(x_train1 , y_train1)
model.fit(x_train1 , y_train1)
y_pred1 = model.predict(x_test1)
poly.fit_transform(x_test1)
y_pred = model.predict(x_test1)
print("MSE: ", metrics.mean_squared_error(y_test1,y_pred1))
print("R squared: ", metrics.r2_score(y_test1,y_pred1))
# Out:
# MSE:  41604240923.57875
# R squared:  0.696797676524969

# %% [markdown]
# As we can see the complexe model (all the features) has a R-squared (testing) score of 0.68 whether it is for linear or polynomial regression
